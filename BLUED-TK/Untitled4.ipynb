# %%
cd /media/sf_datasets/Smarter Devices/BLUED_extracted/BLUED-TK/events/n_req
# Out:
# /media/sf_datasets/Smarter Devices/BLUED_extracted/BLUED-TK/events/n_req

# %%
import os
from matplotlib import rcParams,pyplot as plt 
import seaborn
import numpy as np

# %%
data=np.loadtxt('dataset_1/111_A_20051.784.txt')[:18000]
plt.plot(data)
plt.show()
plt.plot([np.max(data[i:i+200]) for i in range(0,len(data)-200,200)])
plt.show()
